# %%
import matplotlib.pyplot as plt # for plotting
import numpy as np # for sine function
import csv

# %%
t1 = [] # column 0
dataA = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        dataA.append(float(row[1])) # second column

# %%
t2 = [] # column 0
dataB = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t2.append(float(row[0])) # leftmost column
        dataB.append(float(row[1])) # second column

# %%
t3 = [] # column 0
dataC = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t3.append(float(row[0])) # leftmost column
        dataC.append(float(row[1])) # second column

# %%
t4 = [] # column 0
dataD = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t4.append(float(row[0])) # leftmost column
        dataD.append(float(row[1])) # second column

# %%
rate_A=len(dataA)/t1[-1]
rate_B=len(dataB)/t2[-1]
rate_C=len(dataC)/t3[-1]
rate_D=len(dataD)/t4[-1]

# %%
Fs1 = rate_A # sample rate
Ts1 = 1.0/Fs1; # sampling interval
ts1 = np.arange(0,t1[-1],Ts1) # time vector
y1 = dataA # the data to make the fft from
n1 = len(y1) # length of the signal
k1 = np.arange(n1)
T1 = n1/Fs1
frq1 = k1/T1 # two sides frequency range
frq1 = frq1[range(int(n1/2))] # one side frequency range
Y1 = np.fft.fft(y1)/n1 # fft computing and normalization
Y1 = Y1[range(int(n1/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('SigA ', fontsize=16)
ax1.plot(t1,y1,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq1,abs(Y1),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
Fs2 = rate_B # sample rate
Ts2 = 1.0/Fs2; # sampling interval
ts2 = np.arange(0,t2[-2],Ts2) # time vector
y2 = dataB # the data to make the fft from
n2 = len(y2) # length of the signal
k2 = np.arange(n2)
T2 = n2/Fs2
frq2 = k2/T2 # two sides frequency range
frq2 = frq2[range(int(n2/2))] # one side frequency range
Y2 = np.fft.fft(y2)/n2 # fft computing and normalization
Y2 = Y2[range(int(n2/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('SigB ', fontsize=16)
ax1.plot(t2,y2,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq2,abs(Y2),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
Fs3 = rate_C # sample rate
Ts3 = 1.0/Fs3; # sampling interval
ts3 = np.arange(0,t3[-3],Ts3) # time vector
y3 = dataC # the data to make the fft from
n3 = len(y3) # length of the signal
k3 = np.arange(n3)
T3 = n3/Fs3
frq3 = k3/T3 # two sides frequency range
frq3 = frq3[range(int(n3/2))] # one side frequency range
Y3 = np.fft.fft(y3)/n3 # fft computing and normalization
Y3 = Y3[range(int(n3/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('SigC ', fontsize=16)
ax1.plot(t3,y3,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq3,abs(Y3),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
Fs4 = rate_D # sample rate
Ts4 = 1.0/Fs4; # sampling interval
ts4 = np.arange(0,t4[-4],Ts4) # time vector
y4 = dataD # the data to make the fft from
n4 = len(y4) # length of the signal
k4 = np.arange(n4)
T4 = n4/Fs4
frq4 = k4/T4 # two sides frequency range
frq4 = frq4[range(int(n4/2))] # one side frequency range
Y4 = np.fft.fft(y4)/n4 # fft computing and normalization
Y4 = Y4[range(int(n4/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('SigD ', fontsize=16)
ax1.plot(t4,y4,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq4,abs(Y4),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
t1 = [] # column 0
data1 = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
        
x=2000
sum=0
newdata=[]

for i in range(x):
    data.insert(i,0)

for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + data[j+x-i]
    avg=sum/x
    newdata.append(avg)
        
    

#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("MAF SigA 2000 Data Points Averaged")
plt.show()

# %%
#MAF SigB
t1 = [] # column 0
data1 = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
        
x=1000
sum=0
newdata=[]

for i in range(x):
    data.insert(i,0)

for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + data[j+x-i]
    avg=sum/x
    newdata.append(avg)
        
    

#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("MAF SigB 1000 Data Points Averaged")
plt.show()

# %%
#MAF SigC
t1 = [] # column 0
data1 = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
        
x=1000
sum=0
newdata=[]

for i in range(x):
    data.insert(i,0)

for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + data[j+x-i]
    avg=sum/x
    newdata.append(avg)
        
    

#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("MAF SigC 1000 Data Points Averaged")
plt.show()

# %%
#MAF SigD
t1 = [] # column 0
data1 = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
        
x=1000
sum=0
newdata=[]

for i in range(x):
    data.insert(i,0)

for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + data[j+x-i]
    avg=sum/x
    newdata.append(avg)
        
    

#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("MAF SigD 1000 Data Points Averaged")
plt.show()

# %%
##Weighted Average


t1 = [] # column 0
data1 = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

        
A=.9999
B=1-A
new_average=[]
new_average.append(data1[0])

for i in range(1,len(data1)):
    new_average.append( A*new_average[i-1] + B * data1[i])
    

#Plotting FFT's
rate=len(data)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(new_average)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = new_average # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("IIR SigA A=.9999, B=.0001")
plt.show()

# %%
##Weighted Average


t1 = [] # column 0
data1 = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

        
A=.9999
B=1-A
new_average=[]
new_average.append(data1[0])

for i in range(1,len(data1)):
    new_average.append( A*new_average[i-1] + B * data1[i])
    

#Plotting FFT's
#Plot Responses
rate=len(data)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(new_average)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = new_average # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("IIR SigB A=.9999, B=.0001")
plt.show()

# %%
##Weighted Average


t1 = [] # column 0
data1 = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

        
A=.9999
B=1-A
new_average=[]
new_average.append(data1[0])

for i in range(1,len(data)):
    new_average.append( A*new_average[i-1] + B * data1[i])
    

#Plotting FFT's
#Plot Responses
rate=len(data)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(new_average)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = new_average # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("IIR SigC A=.9999, B=.0001")
plt.show()

# %%
##Weighted Average


t1 = [] # column 0
data1 = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

        
A=.99
B=1-A
new_average=[]
new_average.append(data1[0])

for i in range(1,len(data1)):
    new_average.append( A*new_average[i-1] + B * data1[i])
    

#Plotting FFT's
#Plot Responses
rate=len(data)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(new_average)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = new_average # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("IIR SigD A=.99, B=.01")
plt.show()

# %%
##### SigA FIR
h = [
    -0.000050679794726066,
    -0.000041099278318167,
    -0.000031279920668665,
    -0.000021183486597150,
    -0.000010770285292045,
    0.000000000000000000,
    0.000011167446754809,
    0.000022770999889941,
    0.000034847558259864,
    0.000047431049079466,
    0.000060551498686721,
    0.000074234108254511,
    0.000088498343199344,
    0.000103357045109305,
    0.000118815575023601,
    0.000134870996840645,
    0.000151511309510219,
    0.000168714736477861,
    0.000186449080596567,
    0.000204671152403140,
    0.000223326279275218,
    0.000242347902542027,
    0.000261657269119383,
    0.000281163223679941,
    0.000300762106756334,
    0.000320337763510928,
    0.000339761667195315,
    0.000358893160569588,
    0.000377579817760222,
    0.000395657928211038,
    0.000412953103529159,
    0.000429281007152519,
    0.000444448205872873,
    0.000458253141344113,
    0.000470487218795955,
    0.000480936009263626,
    0.000489380560741255,
    0.000495598812776237,
    0.000499367108150093,
    0.000500461794444300,
    0.000498660907473236,
    0.000493745927786584,
    0.000485503600706003,
    0.000473727809671115,
    0.000458221492033063,
    0.000438798585855176,
    0.000415285995764155,
    0.000387525565446236,
    0.000355376044004699,
    0.000318715033091691,
    0.000277440901501588,
    0.000231474653767861,
    0.000180761739242710,
    0.000125273788160487,
    0.000065010261293197,
    0.000000000000000000,
    -0.000069697336247377,
    -0.000143989957415198,
    -0.000222752767634882,
    -0.000305826338672358,
    -0.000393016043088374,
    -0.000484091357342654,
    -0.000578785344322494,
    -0.000676794323931742,
    -0.000777777739462615,
    -0.000881358226495441,
    -0.000987121890034750,
    -0.001094618794499868,
    -0.001203363670049808,
    -0.001312836837542114,
    -0.001422485353209744,
    -0.001531724372895900,
    -0.001639938734420840,
    -0.001746484755374530,
    -0.001850692242341569,
    -0.001951866706278179,
    -0.002049291777482158,
    -0.002142231812333790,
    -0.002229934682745978,
    -0.002311634738053158,
    -0.002386555927898205,
    -0.002453915073551964,
    -0.002512925274028313,
    -0.002562799432345805,
    -0.002602753886341418,
    -0.002632012127569287,
    -0.002649808591023194,
    -0.002655392497711921,
    -0.002648031731496151,
    -0.002602753886341418,
    -0.002562799432345805,
    -0.002512925274028314,
    -0.002453915073551965,
    -0.002386555927898205,
    -0.002311634738053157,
    -0.002229934682745978,
    -0.002142231812333790,
    -0.002049291777482159,
    -0.001951866706278179,
    -0.001850692242341569,
    -0.001746484755374531,
    -0.001639938734420841,
    -0.001531724372895900,
    -0.001422485353209745,
    -0.001312836837542114,
    -0.001203363670049807,
    -0.001094618794499867,
    -0.000987121890034750,
    -0.000881358226495441,
    -0.000777777739462615,
    -0.000676794323931742,
    -0.000578785344322494,
    -0.000484091357342654,
    -0.000393016043088375,
    -0.000305826338672358,
    -0.000222752767634882,
    -0.000143989957415198,
    -0.000069697336247377,
    0.000000000000000000,
    0.000065010261293198,
    0.000125273788160487,
    0.000180761739242710,
    0.000231474653767861,
    0.000277440901501588,
    0.000318715033091691,
    0.000355376044004699,
    0.000387525565446236,
    0.000415285995764155,
    0.000438798585855176,
    0.000458221492033064,
    0.000473727809671115,
    0.000485503600706004,
    0.000493745927786584,
    0.000498660907473236,
    0.000500461794444300,
    0.000499367108150093,
    0.000495598812776237,
    0.000489380560741255,
    0.000480936009263626,
    0.000470487218795956,
    0.000458253141344114,
    0.000444448205872873,
    0.000429281007152519,
    0.000412953103529159,
    0.000395657928211038,
    0.000377579817760223,
    0.000358893160569588,
    0.000339761667195315,
    0.000320337763510927,
    0.000300762106756335,
    0.000281163223679941,
    0.000261657269119383,
    0.000242347902542027,
    0.000223326279275218,
    0.000204671152403140,
    0.000186449080596567,
    0.000168714736477861,
    0.000151511309510219,
    0.000134870996840645,
    0.000118815575023601,
    0.000103357045109305,
    0.000088498343199344,
    0.000074234108254511,
    0.000060551498686721,
    0.000047431049079466,
    0.000034847558259864,
    0.000022770999889941,
    0.000011167446754809,
    0.000000000000000000,
    -0.000010770285292045,
    -0.000021183486597150,
    -0.000031279920668665,
    -0.000041099278318167,
    -0.000050679794726066,
]


t1 = [] # column 0
data1 = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
newdata=[]
x=len(h)
for i in range(x):
    data.insert(i,0)
    
for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + h[i]*data[j+x-i]
    newdata.append(sum)



#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("FIR SigA: Hamming Window Type; 100Hz Cutoff F; 100Hz Bandwith")
plt.show()

# %%
h = [
    -0.000050679794726066,
    -0.000041099278318167,
    -0.000031279920668665,
    -0.000021183486597150,
    -0.000010770285292045,
    0.000000000000000000,
    0.000011167446754809,
    0.000022770999889941,
    0.000034847558259864,
    0.000047431049079466,
    0.000060551498686721,
    0.000074234108254511,
    0.000088498343199344,
    0.000103357045109305,
    0.000118815575023601,
    0.000134870996840645,
    0.000281163223679941,
    0.000261657269119383,
    0.000242347902542027,
    0.000223326279275218,
    0.000204671152403140,
    0.000186449080596567,
    0.000168714736477861,
    0.000151511309510219,
    0.000134870996840645,
    0.000118815575023601,
    0.000103357045109305,
    0.000088498343199344,
    0.000074234108254511,
    0.000060551498686721,
    0.000047431049079466,
    0.000034847558259864,
    0.000022770999889941,
    0.000011167446754809,
    0.000000000000000000,
    -0.000010770285292045,
    -0.000021183486597150,
    -0.000031279920668665,
    -0.000041099278318167,
    -0.000050679794726066,
]

t1 = [] # column 0
data1 = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
newdata=[]
x=len(h)
for i in range(x):
    data.insert(i,0)
    
for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + h[i]*data[j+x-i]
    newdata.append(sum)



#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("FIR SigB: Hamming Window Type; 33Hz Cutoff F; 33Hz Bandwith")
plt.show()

# %%
h = [
    0.001867519746044820,
    0.002275293677911463,
    0.002692845467883248,
    0.003119400211540369,
    0.003554151391578438,
    0.003996262853518041,
    0.004444870878876082,
    0.004899086349965267,
    0.005357997000181999,
    0.005820669743355830,
    0.006286153075466025,
    0.006753479541784039,
    0.007221668262275161,
    0.007689727507889525,
    0.008156657320192495,
    0.008621452166627776,
    0.009083103623574271,
    0.009540603079249766,
    0.009992944448431896,
    0.010439126890909214,
    0.010878157525543523,
    0.011309054131818317,
    0.011730847830767882,
    0.012142585737226980,
    0.012543333575412086,
    0.012932178249941664,
    0.013308230364524597,
    0.013670626680692492,
    0.014018532509122373,
    0.014351144026291085,
    0.014667690509420725,
    0.014967436482914990,
    0.015249683769748768,
    0.015513773441556675,
    0.015759087661469738,
    0.015985051414072162,
    0.016191134117190663,
    0.016376851110586923,
    0.016541765016997088,
    0.016685486971350718,
    0.016807677714403370,
    0.016908048547430839,
    0.016986362145057821,
    0.017042433223728004,
    0.017076129063764694,
    0.017087369883420026,
    0.017076129063764694,
    0.017042433223728004,
    0.016986362145057821,
    0.016908048547430839,
    0.016807677714403370,
    0.016685486971350718,
    0.016541765016997088,
    0.016376851110586923,
    0.016191134117190663,
    0.015985051414072162,
    0.015759087661469738,
    0.015513773441556675,
    0.015249683769748768,
    0.014967436482914990,
    0.014667690509420725,
    0.014351144026291085,
    0.014018532509122373,
    0.013670626680692492,
    0.013308230364524597,
    0.012932178249941664,
    0.012543333575412086,
    0.012142585737226980,
    0.011730847830767882,
    0.011309054131818317,
    0.010878157525543523,
    0.010439126890909214,
    0.009992944448431896,
    0.009540603079249766,
    0.009083103623574271,
    0.008621452166627776,
    0.008156657320192495,
    0.007689727507889525,
    0.007221668262275161,
    0.006753479541784039,
    0.006286153075466025,
    0.005820669743355830,
    0.005357997000181999,
    0.004899086349965267,
    0.004444870878876082,
    0.003996262853518041,
    0.003554151391578438,
    0.003119400211540369,
    0.002692845467883248,
    0.002275293677911463,
    0.001867519746044820,
]

# %%
t1 = [] # column 0
data1 = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
newdata=[]
x=len(h)
for i in range(x):
    data.insert(i,0)
    
for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + h[i]*data[j+x-i]
    newdata.append(sum)



#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("FIR SigC: Rectangular Window Type; 25Hz Cutoff F; 25Hz Bandwith")
plt.show()

# %%
h = [
    -0.000050679794726066,
    -0.000041099278318167,
    -0.000031279920668665,
    -0.000021183486597150,
    -0.000010770285292045,
    0.000000000000000000,
    0.000011167446754809,
    0.000022770999889941,
    0.000034847558259864,
    0.000047431049079466,
    0.000060551498686721,
    0.000074234108254511,
    0.000088498343199344,
    0.000103357045109305,
    0.000118815575023601,
    0.000134870996840645,
    0.000151511309510219,
    0.000168714736477861,
    0.000186449080596567,
    0.000204671152403140,
    0.000223326279275218,
    0.000242347902542027,
    0.000261657269119383,
    0.000281163223679941,
    0.000300762106756334,
    0.000320337763510928,
    0.000339761667195315,
    0.000358893160569588,
    0.000377579817760222,
    0.000395657928211038,
    0.000412953103529159,
    0.000429281007152519,
    0.000444448205872873,
    0.000458253141344113,
    0.000470487218795955,
    0.000480936009263626,
    0.000489380560741255,
    0.000495598812776237,
    0.000499367108150093,
    0.000500461794444300,
    0.000498660907473236,
    0.000493745927786584,
    0.000485503600706003,
    0.000473727809671115,
    0.000458221492033063,
    0.000438798585855176,
    0.000415285995764155,
    0.000387525565446236,
    0.000355376044004699,
    0.000318715033091691,
    0.000277440901501588,
    0.000231474653767861,
    0.000180761739242710,
    0.000125273788160487,
    0.000065010261293197,
    0.000000000000000000,
    -0.000069697336247377,
    -0.000143989957415198,
    -0.000222752767634882,
    -0.000305826338672358,
    -0.000393016043088374,
    -0.000484091357342654,
    -0.000578785344322494,
    -0.000676794323931742,
    -0.000777777739462615,
    -0.000881358226495441,
    -0.000987121890034750,
    -0.001094618794499868,
    -0.001203363670049808,
    -0.001312836837542114,
    -0.001422485353209744,
    -0.001531724372895900,
    -0.001639938734420840,
    -0.001746484755374530,
    -0.001850692242341569,
    -0.001951866706278179,
    -0.002049291777482158,
    -0.002142231812333790,
    -0.002229934682745978,
    -0.002311634738053158,
    -0.002386555927898205,
    -0.002453915073551964,
    -0.002512925274028313,
    -0.002562799432345805,
    -0.002602753886341418,
    -0.002632012127569287,
    -0.002649808591023194,
    -0.002655392497711921,
    -0.002648031731496151,
    -0.002602753886341418,
    -0.002562799432345805,
    -0.002512925274028314,
    -0.002453915073551965,
    -0.002386555927898205,
    -0.002311634738053157,
    -0.002229934682745978,
    -0.002142231812333790,
    -0.002049291777482159,
    -0.001951866706278179,
    -0.001850692242341569,
    -0.001746484755374531,
    -0.001639938734420841,
    -0.001531724372895900,
    -0.001422485353209745,
    -0.001312836837542114,
    -0.001203363670049807,
    -0.001094618794499867,
    -0.000987121890034750,
    -0.000881358226495441,
    -0.000777777739462615,
    -0.000676794323931742,
    -0.000578785344322494,
    -0.000484091357342654,
    -0.000393016043088375,
    -0.000305826338672358,
    -0.000222752767634882,
    -0.000143989957415198,
    -0.000069697336247377,
    0.000000000000000000,
    0.000065010261293198,
    0.000125273788160487,
    0.000180761739242710,
    0.000231474653767861,
    0.000277440901501588,
    0.000318715033091691,
    0.000355376044004699,
    0.000387525565446236,
    0.000415285995764155,
    0.000438798585855176,
    0.000458221492033064,
    0.000473727809671115,
    0.000485503600706004,
    0.000493745927786584,
    0.000498660907473236,
    0.000500461794444300,
    0.000499367108150093,
    0.000495598812776237,
    0.000489380560741255,
    0.000480936009263626,
    0.000470487218795956,
    0.000458253141344114,
    0.000444448205872873,
    0.000429281007152519,
    0.000412953103529159,
    0.000395657928211038,
    0.000377579817760223,
    0.000358893160569588,
    0.000339761667195315,
    0.000320337763510927,
    0.000300762106756335,
    0.000281163223679941,
    0.000261657269119383,
    0.000242347902542027,
    0.000223326279275218,
    0.000204671152403140,
    0.000186449080596567,
    0.000168714736477861,
    0.000151511309510219,
    0.000134870996840645,
    0.000118815575023601,
    0.000103357045109305,
    0.000088498343199344,
    0.000074234108254511,
    0.000060551498686721,
    0.000047431049079466,
    0.000034847558259864,
    0.000022770999889941,
    0.000011167446754809,
    0.000000000000000000,
    -0.000010770285292045,
    -0.000021183486597150,
    -0.000031279920668665,
    -0.000041099278318167,
    -0.000050679794726066,
]

# %%
t1 = [] # column 0
data1 = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t1.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column


data= data1.copy()
newdata=[]
x=len(h)
for i in range(x):
    data.insert(i,0)
    
for j in range(len(data)-x):
    sum = 0
    for i in range(x):
        sum= sum + h[i]*data[j+x-i]
    newdata.append(sum)



#Plot Responses
rate=len(data1)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'black') # plotting the fft

rate=len(newdata)/t1[-1]
Fs = rate# sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t1[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/4 # fft computing and normalization
Y = Y[range(int(n/2))]

plt.loglog(frq,abs(Y),'red') 
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')
plt.title("FIR SigD: Hamming Window Type; 4Hz Cutoff F; 4Hz Bandwith ")
plt.show()
